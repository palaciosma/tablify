# %%
import os
import base64
import requests

# %%
url = "http://localhost:5000/extract"

# %%
test_files = [f for f in os.listdir() if f.endswith(".pdf")]
test_files
# Out:
# ['F24716_AttachmentAExpiring1415PolicySoFComplete.pdf',
#  'sample-invoice.pdf',
#  'wordpress-pdf-invoice-plugin-sample.pdf']

# %%
extraction_schema = [
    {"value_name": "customer_name", "data_type": "string", "value_description": "Name of the customer"},
    {"value_name": "country_of_origin", "data_type": "string", "value_description": "Name of the country the customer resides in"},
    {"value_name": "invoice_number", "data_type": "string", "value_description": "Invoice number"},
    {"value_name": "total_amount", "data_type": "float", "value_description": "Total amount"}
    ]

# %%
payload = {"documents": []}
for file in test_files:
    with open(file, "rb") as f:
        encoded_file = base64.b64encode(f.read()).decode("utf-8")
        file_payload = {
                "file_name": file,
                "file_content": encoded_file,
                "extraction_schema": extraction_schema  
        }
        payload["documents"].append(file_payload)

# %%
payload
# Out:
# {'documents': [{'file_name': 'F24716_AttachmentAExpiring1415PolicySoFComplete.pdf',
#    'file_content': '...',
#    'extraction_schema': [{'value_name': 'customer_name',
#      'data_type': 'string',
#      'value_description': 'Name of the customer'},
#     {'value_name': 'country_of_origin',
#      'data_type': 'string',
#      'value_description': 'Name of the country the customer resides in'},
#     {'value_name': 'invoice_number',
#      'data_type': 'string',
#      'value_description': 'Invoice number'},
#     {'value_name': 'total_amount',
#      'data_type': 'float',
#      'value_description': 'Total amount'}]},
#   {'file_name': 'sample-invoice.pdf',
#    'file_content': '...',
#    'extraction_schema': [{'value_name': 'customer_name',
#      'data_type': 'string',
#      'value_description': 'Name of the customer'},
#     {'value_name': 'country_of_origin',
#      'data_type': 'string',
#      'value_description': 'Name of the country the customer resides in'},
#     {'value_name': 'invoice_number',
#      'data_type': 'string',
#      'value_description': 'Invoice number'},
#     {'value_name': 'total_amount',
#      'data_type': 'float',
#      'value_description': 'Total amount'}]},
#   {'file_name': 'wordpress-pdf-invoice-plugin-sample.pdf',
#    'file_content': '...',
#    'extraction_schema': [{'value_name': 'customer_name',
#      'data_type': 'string',
#      'value_description': 'Name of the customer'},
#     {'value_name': 'country_of_origin',
#      'data_type': 'string',
#      'value_description': 'Name of the country the customer resides in'},
#     {'value_name': 'invoice_number',
#      'data_type': 'string',
#      'value_description': 'Invoice number'},
#     {'value_name': 'total_amount',
#      'data_type': 'float',
#      'value_description': 'Total amount'}]}]}

# %%
payload1 = {
    "job_type": "analyze",
    "file_name": "test_file.pdf",
    "file_content": encoded_file,
    "extraction_schema": None
}

payload2 = {
    "file_name": "test_file.pdf",
    "file_content": encoded_file,
    "extraction_schema": extraction_schema
}

# %%
response = requests.post(url, json=payload)

# %%
response.json()
# Out:
# {'results': [{'file_name': 'F24716_AttachmentAExpiring1415PolicySoFComplete.pdf',
#    'status': 'success',
#    'extracted_fields': {'customer_name': 'STATE OF FLORIDA',
#     'country_of_origin': 'United States',
#     'invoice_number': 'B1262SF0124814',
#     'total_amount': 13206.0},
#    'validated_fields': {'customer_name': 1.0,
#     'country_of_origin': 0.0,
#     'invoice_number': 1.0,
#     'total_amount': 0.0}},
#   {'file_name': 'sample-invoice.pdf',
#    'status': 'success',
#    'extracted_fields': {'customer_name': 'Musterkunde AG',
#     'country_of_origin': 'Germany',
#     'invoice_number': '123100401',
#     'total_amount': 453.53},
#    'validated_fields': {'customer_name': 1.0,
#     'country_of_origin': 0.9,
#     'invoice_number': 1.0,
#     'total_amount': 1.0}},
#   {'file_name': 'wordpress-pdf-invoice-plugin-sample.pdf',
#    'status': 'success',
#    'extracted_fields': {'customer_name': 'Test Business',
#     'country_of_origin': 'Australia',
#     'invoice_number': 'INV-3337',
#     'total_amount': 93.5},
#    'validated_fields': {'customer_name': 1.0,
#     'country_of_origin': 0.0,
#     'invoice_number': 1.0,
#     'total_amount': 1.0}}]}
